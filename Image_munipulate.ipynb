# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
gb = np.array(Image.open('images.jpg'))
plt.figure(figsize=(5,5))
plt.imshow(gb)
plt.show()

# %%
gb = np.array(Image.open('images.jpg'))

# %%
plt.figure(figsize=(5,5))

# %%
plt.imshow(gb)

# %% [markdown]
# # Flipping Image

# %%
image = Image.open("download.jfif")
plt.figure(figsize=(6,6))
plt.imshow(image)
plt.show()

# %%
image = Image.open("images.jpg")

# %%
plt.show()

# %%
plt.show(image)

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

im_flip = ImageOps.flip(image)
plt.figure(figsize=(5, 5))
plt.imshow(im_flip)

# %%
import matplotlib.pyplot as plt
from PIL import Image, ImageOps

# %%
im_flip = ImageOps.flip(image)

# %%
plt.imshow(im_flip)

# %%
im_flip = ImageOps.flip(image)
plt.figure(figsize=(5, 5))
plt.imshow(im_flip)

# %%
import matplotlib.pyplot as plt
from PIL import Image

image = Image.open("images.jpg")
left = 100  # Define the left coordinate
upper = 100  # Define the upper coordinate
right = 300  # Define the right coordinate
lower = 300  # Define the lower coordinate

crop_image = image.crop((left, upper, right, lower))
plt.figure(figsize=(5, 5))
plt.imshow(crop_image)
